# %%
import pandas as pd

df = pd.read_csv('/Users/samuelzheng/Downloads/neu_rmp_updated.csv')
columns_to_check = ['Average Rating (Out of 5)', 'Would Take Again (Percent)', 'Level of Difficulty (Out of 5)']  
df = df.dropna(subset=columns_to_check)
df.head(40)
# Out:
#      First Name Middle Name       Last Name       ID              Department  \
# 0         Anand         NaN       Asthagiri  2894891              Biomedical
# 2       Faizul          NaN             Huq  2854044                Business
# 5         sakib         NaN           miazi  2989886        Computer Science
# 7      Mohammad         NaN     Abderrazzaq  1268571                  Arabic
# 8         Mehdi         NaN           Abedi  2162443             Engineering
# ...         ...         ...             ...      ...                     ...
# 1566       Lora         NaN  Karaoglu Serce  2462322               Sociology
# 1569     Samina       Zaman           Karim  2130636        Entrepreneurship
# 1570    Alireza         NaN          Karimi  1997770  Mechanical Engineering
# 1571   Jennelle         NaN   Kariotis-Rice  2896597              Psychology
# 1572       Yael         NaN       Karlinsky  2750668               Marketing
#
#              Institution Name  \
# 0     Northeastern University
# 2     Northeastern University
# 5     Northeastern University
# 7     Northeastern University
# 8     Northeastern University
# ...                       ...
# 1566  Northeastern University
# 1569  Northeastern University
# 1570  Northeastern University
# 1571  Northeastern University
# 1572  Northeastern University
#
#                                           NEU_Colleges  Institution ID  \
# 0                             College of Science (COS)             696
# 2              D’Amore-McKim School of Business (DMSB)             696
# 5                  Khoury College of Computer Sciences             696
# 7     College of Social Sciences and Humanities (CSSH)             696
# 8                         College of Engineering (COE)             696
# ...                                                ...             ...
# 1566  College of Social Sciences and Humanities (CSSH)             696
# 1569           D’Amore-McKim School of Business (DMSB)             696
# 1570                      College of Engineering (COE)             696
# 1571                  Bouvé College of Health Sciences             696
# 1572           D’Amore-McKim School of Business (DMSB)             696
#
#       Number of Ratings  Average Rating (Out of 5)  \
# 0                   1.0                        5.0
# 2                   7.0                        2.6
# 5                   1.0                        1.0
# 7                  20.0                        4.5
# 8                  21.0                        3.5
# ...                 ...                        ...
# 1566                2.0                        3.0
# 1569               18.0                        5.0
# 1570                3.0                        2.3
# 1571               12.0                        4.7
# 1572                3.0                        1.0
#
#       Would Take Again (Percent)  Level of Difficulty (Out of 5)  \
# 0                           1.00                             3.0
# 2                           0.43                             4.0
# 5                           0.00                             4.0
# 7                           1.00                             2.7
# 8                           0.62                             3.9
# ...                          ...                             ...
# 1566                        0.50                             3.0
# 1569                        1.00                             3.4
# 1570                        0.50                             4.7
# 1571                        0.92                             1.5
# 1572                        0.00                             3.3
#
#                                            Popular Tags  \
# 0     ['Amazing lectures', 'Inspirational', 'Accessi...
# 2     ['Tough grader', 'Participation matters', 'Gro...
# 5     ['Group projects', 'Lots of homework', 'Lectur...
# 7     ['Respected', 'Caring', 'Amazing lectures', 'W...
# 8     ['Get ready to read', 'Hilarious', 'Lots of ho...
# ...                                                 ...
# 1566  ['Tough grader', 'Participation matters', 'Giv...
# 1569  ['Amazing lectures', 'Participation matters', ...
# 1570       ['Lots of homework', 'Graded by few things']
# 1571  ['Amazing lectures', 'Clear grading criteria',...
# 1572        ['Participation matters', 'Group projects']
#
#                                                 Reviews
# 0           Attendance Clarity (color) Easy (color) ...
# 2           Attendance Clarity (color) Easy (color) ...
# 5           Attendance Clarity (color) Easy (color) ...
# 7        Attendance Clarity (color) Easy (color) Hel...
# 8            Attendance Clarity (color) Easy (color)...
# ...                                                 ...
# 1566    Attendance Clarity (color) Easy (color) Help...
# 1569     Attendance Clarity (color) Easy (color) Hel...
# 1570        Attendance Clarity (color) Easy (color) ...
# 1571         Attendance Clarity (color) Easy (color)...
# 1572    Attendance Clarity (color) Easy (color) Help...
#
# [1000 rows x 14 columns]
